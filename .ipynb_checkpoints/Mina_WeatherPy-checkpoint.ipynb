# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import api_key
from pprint import pprint
import openweathermapy as ow

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Print the list to make sure it works
print("Beginning Data Retrieval")
print("-" * 30)

row_count = 1

# Create a list to hold the info parsed 
city_data = []

# Loop through to get the info per city 
for city in cities:
    
    # Create the endpoint URL
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    
    params = {
        "units": "IMPERIAL",  
        "APPID": api_key, 
        "q": city
    }
    
    # Run requests to get the JSON files
    city_response = requests.get(base_url, params=params)
    
    # Print the list of URLS to make sure the loop works
    print(f"Processing Record {row_count} | {city}")
    print(city_response.url)
    row_count += 1
    
    # Use try/except to skip any cities with errors 
    try: 
        city_response_json = city_response.json()
        city_cloudiness = city_response_json["clouds"]["all"]
        country = city_response_json["sys"]["country"]
        city_date = city_response_json["dt"]
        city_humidity = city_response_json["main"]["humidity"]
        city_lat = city_response_json["coord"]["lat"]
        city_lng = city_response_json["coord"]["lon"]
        city_max_temp = city_response_json["main"]["temp_max"]
        city_wind_speed = city_response_json["wind"]["speed"]
        
        # Append the list to a single dictionary for each parameter 
        city_data.append({"City": city, 
                          "Cloudiness": city_cloudiness, 
                          "Country": country, 
                          "Date": city_date, 
                          "Humidity": city_humidity, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp, 
                          "Wind Speed": city_wind_speed})
        
    except KeyError:
        print("City not found. Skipping...")

print("-" * 30)
print("Data Retrieval Complete")
print("-" * 30)
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kapaa
# Processing Record 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lebu
# Processing Record 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hilo
# Processing Record 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=thompson
# Processing Record 5 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bluff
# Processing Record 6 | naze
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=naze
# Processing Record 7 | tanete
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tanete
# Processing Record 8 | gatesville
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=gatesville
# Processing Record 9 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mataura
# Processing Record 10 | verkh-usugli
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=verkh-usugli
# Processing Record 11 | bar
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bar
# Processing Record 12 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=husavik
# Processing Record 13 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=barentsburg
# City not found. Skipping...
# Processing Record 14 | shache
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=shache
# Processing Record 15 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sao+filipe
# Processing Record 16 | airai
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=airai
# Processing Record 17 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cidreira
# Processing Record 18 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pangnirtung
# Processing Record 19 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=souillac
# Processing Record 20 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hay+river
# Processing Record 21 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=belushya+guba
# City not found. Skipping...
# Processing Record 22 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+alfred
# Processing Record 23 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nikolskoye
# Processing Record 24 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=marzuq
# Processing Record 25 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ilulissat
# Processing Record 26 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hobart
# Processing Record 27 | castro
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=castro
# Processing Record 28 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=zhanaozen
# Processing Record 29 | albany
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=albany
# Processing Record 30 | japura
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=japura
# Processing Record 31 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=porto+novo
# Processing Record 32 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=rikitea
# Processing Record 34 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=busselton
# Processing Record 35 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=richards+bay
# Processing Record 36 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=torbay
# Processing Record 37 | mocuba
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mocuba
# Processing Record 38 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ushuaia
# Processing Record 39 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=puerto+ayora
# Processing Record 40 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vaini
# Processing Record 41 | luwingu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luwingu
# Processing Record 42 | oxford
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=oxford
# Processing Record 43 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vardo
# Processing Record 44 | hami
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hami
# Processing Record 45 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=carnarvon
# Processing Record 46 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hofn
# Processing Record 47 | east london
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=east+london
# Processing Record 48 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=batagay-alyta
# Processing Record 49 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jamestown
# Processing Record 50 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ginir
# Processing Record 51 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bambous+virieux
# Processing Record 52 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mar+del+plata
# Processing Record 53 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=karaul
# City not found. Skipping...
# Processing Record 54 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=atuona
# Processing Record 55 | artyk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=artyk
# City not found. Skipping...
# Processing Record 56 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bredasdorp
# Processing Record 57 | sunbury
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sunbury
# Processing Record 58 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sao+joao+da+barra
# Processing Record 59 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=taolanaro
# City not found. Skipping...
# Processing Record 60 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=boa+vista
# Processing Record 61 | padang
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=padang
# Processing Record 62 | new glasgow
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=new+glasgow
# Processing Record 63 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint+anthony
# Processing Record 64 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=te+anau
# Processing Record 65 | baragua
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=baragua
# Processing Record 66 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=berlevag
# Processing Record 67 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=buraydah
# Processing Record 68 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tuktoyaktuk
# Processing Record 69 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sinnamary
# Processing Record 70 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cedar+city
# Processing Record 71 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=verkhnyaya+inta
# Processing Record 72 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=georgetown
# Processing Record 73 | rapid valley
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=rapid+valley
# Processing Record 74 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=yellowknife
# Processing Record 75 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=punta+arenas
# Processing Record 76 | brokopondo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=brokopondo
# Processing Record 77 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saskylakh
# Processing Record 78 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=yar-sale
# Processing Record 79 | dunkirk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dunkirk
# Processing Record 80 | timberlake
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=timberlake
# Processing Record 81 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sibu
# Processing Record 82 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=taoudenni
# Processing Record 83 | ziro
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ziro
# Processing Record 84 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=avarua
# Processing Record 85 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kahului
# Processing Record 86 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ketchikan
# Processing Record 87 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ostrovnoy
# Processing Record 88 | probolinggo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=probolinggo
# Processing Record 89 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=qaqortoq
# Processing Record 90 | lata
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lata
# Processing Record 91 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chapais
# Processing Record 92 | belaya gora
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=belaya+gora
# Processing Record 93 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=qaanaaq
# Processing Record 94 | jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jacareacanga
# Processing Record 95 | lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lavumisa
# Processing Record 96 | olaszliszka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=olaszliszka
# Processing Record 97 | jackson
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jackson
# Processing Record 98 | malko tarnovo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=malko+tarnovo
# Processing Record 99 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 100 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lorengau
# Processing Record 101 | dois vizinhos
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dois+vizinhos
# Processing Record 102 | baker city
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=baker+city
# Processing Record 103 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kodiak
# Processing Record 104 | misratah
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=misratah
# Processing Record 105 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint-philippe
# Processing Record 106 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=deputatskiy
# Processing Record 107 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hobyo
# Processing Record 108 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=longyearbyen
# Processing Record 109 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+lincoln
# Processing Record 110 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=butaritari
# Processing Record 111 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=barrow
# Processing Record 112 | portland
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=portland
# Processing Record 113 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tsihombe
# City not found. Skipping...
# Processing Record 114 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saldanha
# Processing Record 115 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=komsomolskiy
# Processing Record 116 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chokurdakh
# Processing Record 117 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chuy
# Processing Record 118 | manapparai
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=manapparai
# Processing Record 119 | san juan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=san+juan
# Processing Record 120 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+keats
# Processing Record 121 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint+george
# Processing Record 122 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=muroto
# Processing Record 123 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pacifica
# Processing Record 124 | chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chernyshevskiy
# Processing Record 125 | ipixuna
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ipixuna
# Processing Record 126 | banikoara
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=banikoara
# Processing Record 127 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hermanus
# Processing Record 128 | helena
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=helena
# Processing Record 129 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nyurba
# Processing Record 130 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=narsaq
# Processing Record 131 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ossora
# Processing Record 132 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=emerald
# Processing Record 133 | mankera
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mankera
# Processing Record 134 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=san+patricio
# Processing Record 135 | lannion
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lannion
# Processing Record 136 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=namibe
# Processing Record 137 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luderitz
# Processing Record 138 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cabo+san+lucas
# Processing Record 139 | nevsehir
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nevsehir
# Processing Record 140 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=isangel
# Processing Record 141 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=caravelas
# Processing Record 142 | lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lac+du+bonnet
# Processing Record 143 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=phan+thiet
# Processing Record 144 | bermejo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bermejo
# Processing Record 145 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=new+norfolk
# Processing Record 146 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=coahuayana
# Processing Record 147 | machinga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=machinga
# Processing Record 148 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cherskiy
# Processing Record 149 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mahebourg
# Processing Record 150 | chor
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chor
# Processing Record 151 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vila+velha
# Processing Record 152 | salinas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=salinas
# Processing Record 153 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ponta+do+sol
# Processing Record 154 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=fortuna
# Processing Record 155 | temaraia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=temaraia
# City not found. Skipping...
# Processing Record 156 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dwarka
# Processing Record 157 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=alta+floresta
# Processing Record 158 | mpongwe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mpongwe
# Processing Record 159 | taiyuan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=taiyuan
# Processing Record 160 | alvaraes
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=alvaraes
# Processing Record 161 | santa cruz cabralia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=santa+cruz+cabralia
# Processing Record 162 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=petropavlovsk-kamchatskiy
# Processing Record 163 | nome
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nome
# Processing Record 164 | dali
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dali
# Processing Record 165 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+elizabeth
# Processing Record 166 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=havelock
# Processing Record 167 | wagar
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=wagar
# Processing Record 168 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bengkulu
# City not found. Skipping...
# Processing Record 169 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sabang
# Processing Record 170 | harnai
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=harnai
# Processing Record 171 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kavieng
# Processing Record 172 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kavaratti
# Processing Record 173 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hithadhoo
# Processing Record 174 | tooele
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tooele
# Processing Record 175 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+hardy
# Processing Record 176 | mandapam
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mandapam
# Processing Record 177 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sitka
# Processing Record 178 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mayo
# Processing Record 179 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=umzimvubu
# City not found. Skipping...
# Processing Record 180 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kununurra
# Processing Record 181 | gudari
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=gudari
# Processing Record 182 | queanbeyan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=queanbeyan
# Processing Record 183 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ternate
# Processing Record 184 | lander
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lander
# Processing Record 185 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=norman+wells
# Processing Record 186 | nokaneng
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nokaneng
# Processing Record 187 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=leningradskiy
# Processing Record 188 | nosy varika
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nosy+varika
# Processing Record 189 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cockburn+town
# Processing Record 190 | shagonar
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=shagonar
# Processing Record 191 | khargupur
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=khargupur
# Processing Record 192 | solano
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=solano
# Processing Record 193 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=neiafu
# Processing Record 194 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=grindavik
# Processing Record 195 | stonewall
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=stonewall
# Processing Record 196 | gat
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=gat
# Processing Record 197 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ribeira+grande
# Processing Record 198 | north platte
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=north+platte
# Processing Record 199 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=amderma
# City not found. Skipping...
# Processing Record 200 | aconibe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=aconibe
# Processing Record 201 | daru
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=daru
# Processing Record 202 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=fort+nelson
# Processing Record 203 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bethel
# Processing Record 204 | ferme-neuve
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ferme-neuve
# Processing Record 205 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=comodoro+rivadavia
# Processing Record 206 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=faanui
# Processing Record 207 | novokruchininskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=novokruchininskiy
# Processing Record 208 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=flin+flon
# Processing Record 209 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=plettenberg+bay
# Processing Record 210 | churapcha
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=churapcha
# Processing Record 211 | korla
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=korla
# City not found. Skipping...
# Processing Record 212 | wazzan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=wazzan
# City not found. Skipping...
# Processing Record 213 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=viedma
# Processing Record 214 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nizhneyansk
# City not found. Skipping...
# Processing Record 215 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=teahupoo
# Processing Record 216 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tuatapere
# Processing Record 217 | lodja
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lodja
# Processing Record 218 | senanga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=senanga
# Processing Record 219 | hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hukuntsi
# Processing Record 220 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nizwa
# Processing Record 221 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint-louis
# Processing Record 222 | ishigaki
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ishigaki
# Processing Record 223 | boffa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=boffa
# Processing Record 224 | port augusta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port+augusta
# Processing Record 225 | ulagan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ulagan
# Processing Record 226 | xifeng
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=xifeng
# Processing Record 227 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=goderich
# Processing Record 228 | asau
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=asau
# City not found. Skipping...
# Processing Record 229 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=esperance
# Processing Record 230 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=general+roca
# Processing Record 231 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bonavista
# Processing Record 232 | moyale
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=moyale
# Processing Record 233 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=katsuura
# Processing Record 234 | quepos
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=quepos
# Processing Record 235 | puerto ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=puerto+ayacucho
# Processing Record 236 | moses lake
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=moses+lake
# Processing Record 237 | bonga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bonga
# Processing Record 238 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=talnakh
# Processing Record 239 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tasiilaq
# Processing Record 240 | muros
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=muros
# Processing Record 241 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=provideniya
# Processing Record 242 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mackenzie
# Processing Record 243 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dikson
# Processing Record 244 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lolua
# City not found. Skipping...
# Processing Record 245 | masunga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=masunga
# Processing Record 246 | vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vestmanna
# Processing Record 247 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kysyl-syr
# Processing Record 248 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ixtapa
# Processing Record 249 | sembe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sembe
# City not found. Skipping...
# Processing Record 250 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cape+town
# Processing Record 251 | kouqian
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kouqian
# Processing Record 252 | luchegorsk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luchegorsk
# Processing Record 253 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=aklavik
# Processing Record 254 | belene
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=belene
# Processing Record 255 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=taltal
# Processing Record 256 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=katangli
# Processing Record 257 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=acarau
# City not found. Skipping...
# Processing Record 258 | lincoln
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lincoln
# Processing Record 259 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=arraial+do+cabo
# Processing Record 260 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=borogontsy
# Processing Record 261 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=san+quintin
# Processing Record 262 | palencia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=palencia
# Processing Record 263 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=beringovskiy
# Processing Record 264 | plaridel
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=plaridel
# Processing Record 265 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lagoa
# Processing Record 266 | iskateley
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=iskateley
# Processing Record 267 | brigantine
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=brigantine
# Processing Record 268 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=chagda
# City not found. Skipping...
# Processing Record 269 | belawan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=belawan
# Processing Record 270 | arman
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=arman
# Processing Record 271 | anito
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=anito
# Processing Record 272 | kjollefjord
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kjollefjord
# Processing Record 273 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bathsheba
# Processing Record 274 | severnyy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=severnyy
# City not found. Skipping...
# Processing Record 275 | madhupur
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=madhupur
# Processing Record 276 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pundaguitan
# Processing Record 277 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=acapulco
# Processing Record 278 | aksaray
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=aksaray
# Processing Record 279 | jarjis
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jarjis
# City not found. Skipping...
# Processing Record 280 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=guerrero+negro
# Processing Record 281 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=broken+hill
# Processing Record 282 | jinka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jinka
# Processing Record 283 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tabou
# Processing Record 284 | maltahohe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=maltahohe
# Processing Record 285 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tessalit
# Processing Record 286 | sandy bay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sandy+bay
# Processing Record 287 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=victoria
# Processing Record 288 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pevek
# Processing Record 289 | burica
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=burica
# City not found. Skipping...
# Processing Record 290 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=xichang
# Processing Record 291 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pangody
# Processing Record 292 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=khatanga
# Processing Record 293 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=toliary
# City not found. Skipping...
# Processing Record 294 | bongandanga
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bongandanga
# Processing Record 295 | luwuk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luwuk
# Processing Record 296 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tumannyy
# City not found. Skipping...
# Processing Record 297 | buluang
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=buluang
# Processing Record 298 | abengourou
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=abengourou
# Processing Record 299 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=qui+nhon
# City not found. Skipping...
# Processing Record 300 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mandalgovi
# Processing Record 301 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=upernavik
# Processing Record 302 | las rozas de madrid
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=las+rozas+de+madrid
# Processing Record 303 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=attawapiskat
# City not found. Skipping...
# Processing Record 304 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tautira
# Processing Record 305 | nazca
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nazca
# Processing Record 306 | marang
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=marang
# City not found. Skipping...
# Processing Record 307 | kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kedrovyy
# Processing Record 308 | quelimane
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=quelimane
# Processing Record 309 | hailun
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hailun
# Processing Record 310 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lazaro+cardenas
# Processing Record 311 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tommot
# Processing Record 312 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bilibino
# Processing Record 313 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lavrentiya
# Processing Record 314 | yabrud
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=yabrud
# Processing Record 315 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint-francois
# Processing Record 316 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=huilong
# Processing Record 317 | luba
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luba
# Processing Record 318 | ust-maya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ust-maya
# Processing Record 319 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mys+shmidta
# City not found. Skipping...
# Processing Record 320 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=klaksvik
# Processing Record 321 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=fukue
# Processing Record 322 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vaitupu
# City not found. Skipping...
# Processing Record 323 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lompoc
# Processing Record 324 | akyab
# ...
# Processing Record 512 | taksimo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=taksimo
# Processing Record 513 | elbrus
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=elbrus
# Processing Record 514 | masjed-e soleyman
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=masjed-e+soleyman
# City not found. Skipping...
# Processing Record 515 | ndele
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ndele
# City not found. Skipping...
# Processing Record 516 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mackay
# Processing Record 517 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hasaki
# Processing Record 518 | yerky
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=yerky
# Processing Record 519 | zilair
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=zilair
# Processing Record 520 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=champerico
# Processing Record 521 | binika
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=binika
# Processing Record 522 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hervey+bay
# Processing Record 523 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=iqaluit
# Processing Record 524 | dhangadhi
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dhangadhi
# Processing Record 525 | dudinka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dudinka
# Processing Record 526 | bolu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bolu
# Processing Record 527 | deori
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=deori
# Processing Record 528 | la massana
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=la+massana
# Processing Record 529 | damphu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=damphu
# Processing Record 530 | hihifo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hihifo
# City not found. Skipping...
# Processing Record 531 | kamariotissa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kamariotissa
# Processing Record 532 | barcelos
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=barcelos
# Processing Record 533 | paithan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=paithan
# Processing Record 534 | la cruz
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=la+cruz
# Processing Record 535 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=eureka
# Processing Record 536 | gambela
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=gambela
# Processing Record 537 | altay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=altay
# Processing Record 538 | santa marta
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=santa+marta
# Processing Record 539 | los alamos
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=los+alamos
# Processing Record 540 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=beloha
# Processing Record 541 | tevriz
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tevriz
# Processing Record 542 | mikkeli
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mikkeli
# Processing Record 543 | wangkui
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=wangkui
# Processing Record 544 | bogotol
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=bogotol
# Processing Record 545 | keuruu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=keuruu
# Processing Record 546 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tamiahua
# Processing Record 547 | pimentel
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pimentel
# Processing Record 548 | jasper
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jasper
# Processing Record 549 | xiazhen
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=xiazhen
# Processing Record 550 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kimbe
# Processing Record 551 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=codrington
# Processing Record 552 | jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jiuquan
# Processing Record 553 | muscle shoals
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=muscle+shoals
# Processing Record 554 | kolpashevo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kolpashevo
# Processing Record 555 | dublin
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=dublin
# Processing Record 556 | tual
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tual
# Processing Record 557 | socorro
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=socorro
# Processing Record 558 | talara
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=talara
# Processing Record 559 | lamas
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lamas
# Processing Record 560 | mancio lima
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mancio+lima
# City not found. Skipping...
# Processing Record 561 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=meulaboh
# Processing Record 562 | springfield
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=springfield
# Processing Record 563 | goya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=goya
# Processing Record 564 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kawalu
# Processing Record 565 | saint-michel-des-saints
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=saint-michel-des-saints
# Processing Record 566 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nalut
# Processing Record 567 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=la+ronge
# Processing Record 568 | pala
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=pala
# Processing Record 569 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=strezhevoy
# Processing Record 570 | khakhea
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=khakhea
# Processing Record 571 | ko samui
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=ko+samui
# Processing Record 572 | umuahia
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=umuahia
# Processing Record 573 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tiznit
# Processing Record 574 | humaita
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=humaita
# Processing Record 575 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=mayor+pablo+lagerenza
# Processing Record 576 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=neuquen
# Processing Record 577 | west bay
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=west+bay
# Processing Record 578 | porbandar
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=porbandar
# Processing Record 579 | albacete
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=albacete
# Processing Record 580 | tinaquillo
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=tinaquillo
# Processing Record 581 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=viligili
# City not found. Skipping...
# Processing Record 582 | kudat
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kudat
# Processing Record 583 | karauzyak
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=karauzyak
# City not found. Skipping...
# Processing Record 584 | cortez
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=cortez
# Processing Record 585 | macae
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=macae
# Processing Record 586 | luancheng
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=luancheng
# Processing Record 587 | vitim
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vitim
# Processing Record 588 | lima
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lima
# Processing Record 589 | sola
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=sola
# Processing Record 590 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lakes+entrance
# Processing Record 591 | vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=vilyuysk
# Processing Record 592 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=maceio
# Processing Record 593 | lamar
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=lamar
# Processing Record 594 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kaitangata
# Processing Record 595 | areosa
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=areosa
# Processing Record 596 | buariki
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=buariki
# City not found. Skipping...
# Processing Record 597 | andijon
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=andijon
# Processing Record 598 | kutahya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kutahya
# Processing Record 599 | nicoya
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=nicoya
# Processing Record 600 | kinablangan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kinablangan
# Processing Record 601 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=salalah
# Processing Record 602 | hohhot
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hohhot
# Processing Record 603 | florianopolis
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=florianopolis
# Processing Record 604 | college
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=college
# Processing Record 605 | zabol
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=zabol
# Processing Record 606 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=quatre+cocos
# Processing Record 607 | hobbs
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=hobbs
# Processing Record 608 | maroantsetra
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=maroantsetra
# Processing Record 609 | juneau
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=juneau
# Processing Record 610 | simimbaan
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=simimbaan
# Processing Record 611 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=oktyabrskiy
# Processing Record 612 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=port-gentil
# Processing Record 613 | xinqing
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=xinqing
# Processing Record 614 | menongue
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=menongue
# Processing Record 615 | meyungs
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=meyungs
# City not found. Skipping...
# Processing Record 616 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=burnie
# Processing Record 617 | follonica
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=follonica
# Processing Record 618 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=kloulklubed
# Processing Record 619 | jiutepec
# http://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&APPID=69d9986f9a8c45c9f8fc0133502b5ab0&q=jiutepec
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Create a DataFrame with the information received 
city_data_pd = pd.DataFrame(city_data)
city_data_pd.count()
# Out:
# City          559
# Cloudiness    559
# Country       559
# Date          559
# Humidity      559
# Lat           559
# Lng           559
# Max Temp      559
# Wind Speed    559
# dtype: int64

# %%
# Display the City DataFrame
city_data_pd.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     kapaa           1      US  1553748354        78  22.08 -159.32
# 1      lebu          92      ET  1553748409        73   8.96   38.73
# 2      hilo          75      US  1553748196        73  19.71 -155.08
# 3  thompson          40      CA  1553745600        72  55.74  -97.86
# 4     bluff         100      AU  1553748410        98 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0     75.20        4.70
# 1     60.92        3.38
# 2     73.99       10.29
# 3     14.00        9.17
# 4     71.54       12.10

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Max Temp"], marker="o")
plt.title("City Latitude vs. Max Temperature (11/18/2017)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Humidity"], marker="o")
plt.title("City Latitude vs. Humidity (11/18/2017)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Cloudiness"], marker="o")
plt.title("City Latitude vs. Cloudiness (11/18/2017)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_pd["Lat"], city_data_pd["Wind Speed"], marker="o")
plt.title("City Latitude vs. Wind Speed (11/18/2017)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
